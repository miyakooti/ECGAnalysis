# %% [markdown]
# - rest
# - practice
# - boredom
# - flow
# - ultra
# - overload

# %%
import numpy as np
import pandas as pd
import heartpy as hp
from matplotlib import pyplot as plt

# option command v でフルパスをコピー
# hrdata = hp.get_data('/Users/miyakooti/repositories/arai_MATLAB_program/data/20221220_kumakura/SSSEP_20221220T152825_kumakura_rest_good.mat')
hrdata = hp.get_data("/Users/miyakooti/repositories/arai_MATLAB_program/csv/0_kumakura/ECG/ECG_kumakura_rest.csv", delim = ",", column_name = "ECG") # numpy.ndarray
fs = 500.0

# %%
len(hrdata)
# Out:
# 156358

# %%
sec = len(hrdata)/500
print(f"計測時間は{sec}秒です")
# Out:
# 計測時間は312.716秒です

# %%
# スライスする場合はコメントアウトを外す
# hrdata = hrdata[0:int(30*fs)]

# %% [markdown]
# ### ここで取得されたのは numpy.ndarray型

# %%
working_data, measures = hp.process(hrdata, fs, report_time=True, calc_freq=True)
# Out:
# Finished in 0.151954 sec

# %% [markdown]
# ### データ数多すぎるので、論文とかで画像載っけるときは生データをスライスしてもイイかも

# %% [markdown]
# [参考文献](https://note.nkmk.me/python-numpy-ndarray-slice/)

# %% [markdown]
# ### plot

# %%
hp.plotter(working_data, measures)
# Out:
# /Users/miyakooti/opt/anaconda3/envs/HeartPy/lib/python3.7/site-packages/heartpy/visualizeutils.py:119: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
print("LF：", measures["lf"])
print("HF：", measures["hf"])
print("LF/HF：", measures["lf/hf"])
# Out:
# LF： 206.38421472062007
# HF： 482.5739930212709
# LF/HF： 0.4276737198963042

# %%
print(measures)
# Out:
# {'bpm': 73.67887808037345, 'ibi': 814.3446475195823, 'sdnn': 40.28056002263842, 'sdsd': 20.44006683788928, 'rmssd': 36.81366693632175, 'pnn20': 0.6178010471204188, 'pnn50': 0.19633507853403143, 'hr_mad': 30.0, 'sd1': 26.031041894798975, 'sd2': 50.70237136892612, 's': 4146.385678100192, 'sd1/sd2': 0.5134087655464686, 'breathingrate': 0.32062586168200324, 'vlf': 363.48329092276606, 'lf': 206.38421472062007, 'hf': 482.5739930212709, 'lf/hf': 0.4276737198963042, 'p_total': 1052.441498664657, 'vlf_perc': 34.537149227197474, 'lf_perc': 19.61004150658078, 'hf_perc': 45.85280926622175, 'lf_nu': 29.955984615824352, 'hf_nu': 70.04401538417564}

# %%
rr_interval = pd.DataFrame(working_data["RR_list"])
rr_interval.to_csv("/Users/miyakooti/repositories/arai_MATLAB_program/csv/0_kumakura")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/4_/zl9w1kqn3wj4cv0147kh6bc40000gn/T/ipykernel_33262/962733890.py in <module>
#       1 rr_interval = pd.DataFrame(working_data["RR_list"])
# ----> 2 rr_interval.to_csv("csv/RR_interval_kumakura.csv")
#
# ~/opt/anaconda3/envs/HeartPy/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~/opt/anaconda3/envs/HeartPy/lib/python3.7/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/opt/anaconda3/envs/HeartPy/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~/opt/anaconda3/envs/HeartPy/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'csv/RR_interval_kumakura.csv'

# %%
measures
# Out:
# {'bpm': 73.67887808037345,
#  'ibi': 814.3446475195823,
#  'sdnn': 40.28056002263842,
#  'sdsd': 20.44006683788928,
#  'rmssd': 36.81366693632175,
#  'pnn20': 0.6178010471204188,
#  'pnn50': 0.19633507853403143,
#  'hr_mad': 30.0,
#  'sd1': 26.031041894798975,
#  'sd2': 50.70237136892612,
#  's': 4146.385678100192,
#  'sd1/sd2': 0.5134087655464686,
#  'breathingrate': 0.32062586168200324,
#  'vlf': 363.48329092276606,
#  'lf': 206.38421472062007,
#  'hf': 482.5739930212709,
#  'lf/hf': 0.4276737198963042,
#  'p_total': 1052.441498664657,
#  'vlf_perc': 34.537149227197474,
#  'lf_perc': 19.61004150658078,
#  'hf_perc': 45.85280926622175,
#  'lf_nu': 29.955984615824352,
#  'hf_nu': 70.04401538417564}

# %%
type(measures)
# Out:
# dict
