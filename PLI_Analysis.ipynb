# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['font.family'] = 'MS Gothic'

# %%
df = pd.read_csv("csv/0_kumakura/PLIdata/concentration_kumakura_practice.csv")

# %%
df.head(5)
# Out:
#         FC3       FC4       FCz
# 0  0.165443 -0.073156  0.082434
# 1  0.165689 -0.071658  0.082461
# 2  0.166586 -0.071889  0.082411
# 3  0.172363 -0.075421  0.082282
# 4  0.175152 -0.075737  0.082611

# %%
df.plot()
plt.title("time series variation of PLI")
plt.xlabel("seconds")
plt.ylabel("PLI")
# Out:
# Text(0, 0.5, 'PLI')
